# %%
import nltk

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# [u'austen-emma.txt',
#  u'austen-persuasion.txt',
#  u'austen-sense.txt',
#  u'bible-kjv.txt',
#  u'blake-poems.txt',
#  u'bryant-stories.txt',
#  u'burgess-busterbrown.txt',
#  u'carroll-alice.txt',
#  u'chesterton-ball.txt',
#  u'chesterton-brown.txt',
#  u'chesterton-thursday.txt',
#  u'edgeworth-parents.txt',
#  u'melville-moby_dick.txt',
#  u'milton-paradise.txt',
#  u'shakespeare-caesar.txt',
#  u'shakespeare-hamlet.txt',
#  u'shakespeare-macbeth.txt',
#  u'whitman-leaves.txt']

# %%
md=nltk.corpus.gutenberg.words("melville-moby_dick.txt")

# %%
md
# Out:
# [u'[', u'Moby', u'Dick', u'by', u'Herman', u'Melville', ...]

# %%
md[1:10]
# Out:
# [u'Moby',
#  u'Dick',
#  u'by',
#  u'Herman',
#  u'Melville',
#  u'1851',
#  u']',
#  u'ETYMOLOGY',
#  u'.']

# %%
md.count("Moby")
# Out:
# 84

# %%
md.count("The")
# Out:
# 612

# %%
len(md)
# Out:
# 260819

# %%
md_set=set(md)

# %%
len(md_set)
# Out:
# 19317

# %%
from __future__ import division

# %%
len(md)/len(md_set)
# Out:
# 13.502044830977896

# %%
md_sent=nltk.corpus.gutenberg.sents("melville-moby_dick.txt")

# %%
len(md_sent)
# Out:
# 10059

# %%
len(md)/len(md_sent)
# Out:
# 25.928919375683467

# %%
from nltk.corpus import inaugural

# %%
inaugural.fileids(
)
# Out:
# [u'1789-Washington.txt',
#  u'1793-Washington.txt',
#  u'1797-Adams.txt',
#  u'1801-Jefferson.txt',
#  u'1805-Jefferson.txt',
#  u'1809-Madison.txt',
#  u'1813-Madison.txt',
#  u'1817-Monroe.txt',
#  u'1821-Monroe.txt',
#  u'1825-Adams.txt',
#  u'1829-Jackson.txt',
#  u'1833-Jackson.txt',
#  u'1837-VanBuren.txt',
#  u'1841-Harrison.txt',
#  u'1845-Polk.txt',
#  u'1849-Taylor.txt',
#  u'1853-Pierce.txt',
#  u'1857-Buchanan.txt',
#  u'1861-Lincoln.txt',
#  u'1865-Lincoln.txt',
#  u'1869-Grant.txt',
#  u'1873-Grant.txt',
#  u'1877-Hayes.txt',
#  u'1881-Garfield.txt',
#  u'1885-Cleveland.txt',
#  u'1889-Harrison.txt',
#  u'1893-Cleveland.txt',
#  u'1897-McKinley.txt',
#  u'1901-McKinley.txt',
#  u'1905-Roosevelt.txt',
#  u'1909-Taft.txt',
#  u'1913-Wilson.txt',
#  u'1917-Wilson.txt',
#  u'1921-Harding.txt',
#  u'1925-Coolidge.txt',
#  u'1929-Hoover.txt',
#  u'1933-Roosevelt.txt',
#  u'1937-Roosevelt.txt',
#  u'1941-Roosevelt.txt',
#  u'1945-Roosevelt.txt',
#  u'1949-Truman.txt',
# ...

# %%
for speech in inaugural.fileids():
    words_total=len(inaugural.words(speech))
    print words_total,speech
# Out:
# 1538 1789-Washington.txt
# 147 1793-Washington.txt
# 2585 1797-Adams.txt
# 1935 1801-Jefferson.txt
# 2384 1805-Jefferson.txt
# 1265 1809-Madison.txt
# 1304 1813-Madison.txt
# 3693 1817-Monroe.txt
# 4909 1821-Monroe.txt
# 3150 1825-Adams.txt
# 1208 1829-Jackson.txt
# 1267 1833-Jackson.txt
# 4171 1837-VanBuren.txt
# 9165 1841-Harrison.txt
# 5196 1845-Polk.txt
# 1182 1849-Taylor.txt
# 3657 1853-Pierce.txt
# 3098 1857-Buchanan.txt
# 4005 1861-Lincoln.txt
# 785 1865-Lincoln.txt
# 1239 1869-Grant.txt
# 1478 1873-Grant.txt
# 2724 1877-Hayes.txt
# 3239 1881-Garfield.txt
# 1828 1885-Cleveland.txt
# 4750 1889-Harrison.txt
# 2153 1893-Cleveland.txt
# 4371 1897-McKinley.txt
# 2450 1901-McKinley.txt
# 1091 1905-Roosevelt.txt
# 5846 1909-Taft.txt
# 1905 1913-Wilson.txt
# 1656 1917-Wilson.txt
# 3756 1921-Harding.txt
# 4442 1925-Coolidge.txt
# 3890 1929-Hoover.txt
# 2063 1933-Roosevelt.txt
# 2019 1937-Roosevelt.txt
# 1536 1941-Roosevelt.txt
# 637 1945-Roosevelt.txt
# 2528 1949-Truman.txt
# ...

# %%
speech_len=[(len(inaugural.words(speech)),speech)for speech in inaugural.fileids()]

# %%
speech_len
# Out:
# [(1538, u'1789-Washington.txt'),
#  (147, u'1793-Washington.txt'),
#  (2585, u'1797-Adams.txt'),
#  (1935, u'1801-Jefferson.txt'),
#  (2384, u'1805-Jefferson.txt'),
#  (1265, u'1809-Madison.txt'),
#  (1304, u'1813-Madison.txt'),
#  (3693, u'1817-Monroe.txt'),
#  (4909, u'1821-Monroe.txt'),
#  (3150, u'1825-Adams.txt'),
#  (1208, u'1829-Jackson.txt'),
#  (1267, u'1833-Jackson.txt'),
#  (4171, u'1837-VanBuren.txt'),
#  (9165, u'1841-Harrison.txt'),
#  (5196, u'1845-Polk.txt'),
#  (1182, u'1849-Taylor.txt'),
#  (3657, u'1853-Pierce.txt'),
#  (3098, u'1857-Buchanan.txt'),
#  (4005, u'1861-Lincoln.txt'),
#  (785, u'1865-Lincoln.txt'),
#  (1239, u'1869-Grant.txt'),
#  (1478, u'1873-Grant.txt'),
#  (2724, u'1877-Hayes.txt'),
#  (3239, u'1881-Garfield.txt'),
#  (1828, u'1885-Cleveland.txt'),
#  (4750, u'1889-Harrison.txt'),
#  (2153, u'1893-Cleveland.txt'),
#  (4371, u'1897-McKinley.txt'),
#  (2450, u'1901-McKinley.txt'),
#  (1091, u'1905-Roosevelt.txt'),
#  (5846, u'1909-Taft.txt'),
# ...

# %%
max(speech_len)
# Out:
# (9165, u'1841-Harrison.txt')

# %%
    min(speech_len)
# Out:
# (147, u'1793-Washington.txt')

# %%
import pandas as pd

# %%
data=pd.DataFrame([int(speech[:4]),len(inaugural.words(speech))/len(inaugural.sents(speech))] for speech in inaugural.fileids())

# %%
data.head(10)
# Out:
#       0          1
# 0  1789  64.083333
# 1  1793  36.750000
# 2  1797  69.864865
# 3  1801  46.071429
# 4  1805  52.977778
# 5  1809  60.238095
# 6  1813  39.515152
# 7  1817  30.270492
# 8  1821  38.054264
# 9  1825  42.567568

# %%
data.columns=['Year',"Average WPS"]

# %%
data.head()
# Out:
#    Year  Average WPS
# 0  1789    64.083333
# 1  1793    36.750000
# 2  1797    69.864865
# 3  1801    46.071429
# 4  1805    52.977778

# %%
import matplotlib
# %matplotlib inline

# %%
data.plot("Year",figsize=(15,5))

# %%
alice=nltk.corpus.gutenberg.words("carroll-alice.txt")

# %%
alice_fd=nltk.FreqDist(alice)

# %%
alice_fd
# Out:
# FreqDist({u'secondly': 2,
#           u'pardon': 6,
#           u'hatters': 1,
#           u'saves': 1,
#           u'knelt': 1,
#           u'four': 8,
#           u'Does': 2,
#           u'sleep': 6,
#           u'hanging': 3,
#           u'ringlets': 2,
#           u'oldest': 1,
#           u'hate': 2,
#           u'assembled': 2,
#           u'forget': 2,
#           u'whose': 2,
#           u'swam': 5,
#           u'blacking': 1,
#           u'presents': 2,
#           u'under': 16,
#           u'inwards': 1,
#           u'sorry': 1,
#           u'worth': 4,
#           u'barley': 1,
#           u'Mystery': 2,
#           u'struck': 2,
#           u'rise': 1,
#           u'every': 12,
#           u'fireplace': 1,
#           u'school': 6,
#           u'prize': 1,
#           u'wooden': 1,
#           u'pinch': 1,
#           u'NEAR': 1,
#           u'Dinn': 1,
#           u'Go': 3,
#           u'favoured': 1,
#           u'leaders': 1,
#           u'tired': 7,
# ...

# %%
alice_fd['Rabbit']
# Out:
# 45

# %%
alice_fd.most_common(20)
# Out:
# [(u',', 1993),
#  (u"'", 1731),
#  (u'the', 1527),
#  (u'and', 802),
#  (u'.', 764),
#  (u'to', 725),
#  (u'a', 615),
#  (u'I', 543),
#  (u'it', 527),
#  (u'she', 509),
#  (u'of', 500),
#  (u'said', 456),
#  (u",'", 397),
#  (u'Alice', 396),
#  (u'in', 357),
#  (u'was', 352),
#  (u'you', 345),
#  (u"!'", 278),
#  (u'that', 275),
#  (u'as', 246)]

# %%
alice_fd.hapaxes() #1In corpus linguistics, a hapax legomenon (/ˈhæpəks lᵻˈɡɒmᵻnɒn/ also /ˈhæpæks/ or /ˈheɪpæks/;[1][2] pl. hapax legomena; sometimes abbreviated to hapax, pl. hapaxes) is
#a word that occurs only once within a context, either in the written record of an entire language,
#in the works of an author, or in a single text. The term is sometimes incorrectly used to describe a word 
#that occurs in just one of an author's works, even though it occurs more than once in that work. Hapax legomenon 
#is a transliteration of Greek ἅπαξ λεγόμενον, meaning "(something) said (only) once".[3]
# Out:
# [u'Tut',
#  u'saves',
#  u'knelt',
#  u'oldest',
#  u'consider',
#  u'YOURS',
#  u'inwards',
#  u'sorry',
#  u'Nearly',
#  u'mournful',
#  u'rise',
#  u'fireplace',
#  u'prize',
#  u'wooden',
#  u'pinch',
#  u'NEAR',
#  u'favoured',
#  u'leaders',
#  u'feathers',
#  u'BEG',
#  u'BEE',
#  u'elegant',
#  u'louder',
#  u'CURTSEYING',
#  u'machines',
#  u'shining',
#  u'VOICE',
#  u'hide',
#  u'pace',
#  u'thunder',
#  u'weren',
#  u'Game',
#  u'conduct',
#  u'wrapping',
#  u'protection',
#  u'cardboard',
#  u'daughter',
#  u'Herald',
#  u'smoke',
#  u'grumbled',
#  u'explained',
#  u'patience',
#  u'drowned',
#  u'punching',
#  u'blacking',
#  u'insult',
#  u'overhead',
#  u'leant',
#  u'peeping',
#  u'Rule',
#  u'adjourn',
#  u'locked',
#  u'worm',
#  u'obstacle',
#  u'rosetree',
#  u'Visit',
#  u'flung',
#  u'returned',
#  u'Tillie',
#  u'complaining',
#  u'agony',
#  u'LL',
#  u'returning',
#  u'Jack',
#  u'III',
#  u'Zealand',
#  u'poker',
#  u'flustered',
#  u'lad',
#  u'ladder',
# ...

# %%
names_tuple=[("Group A","Kashyap"),("Group A","Savan"),("Group A","Vishal"),("Group B","Mahir"),("Group B","Sameer"),("Group B","Mahir")]

# %%
names_tuple
# Out:
# [('Group A', 'Kashyap'),
#  ('Group A', 'Savan'),
#  ('Group A', 'Vishal'),
#  ('Group B', 'Mahir'),
#  ('Group B', 'Sameer'),
#  ('Group B', 'Mahir')]

# %%
nltk.FreqDist(names_tuple)
# Out:
# FreqDist({('Group A', 'Kashyap'): 1,
#           ('Group A', 'Savan'): 1,
#           ('Group A', 'Vishal'): 1,
#           ('Group B', 'Mahir'): 2,
#           ('Group B', 'Sameer'): 1})

# %%
nltk.ConditionalFreqDist(names_tuple)
# Out:
# ConditionalFreqDist(nltk.probability.FreqDist,
#                     {'Group A': FreqDist({'Kashyap': 1,
#                                'Savan': 1,
#                                'Vishal': 1}),
#                      'Group B': FreqDist({'Mahir': 2, 'Sameer': 1})})

# %% [markdown]
# *informative Words*

# %%
alice_fd_100=alice_fd.most_common(100)

# %%
moby=nltk.corpus.gutenberg.words("melville-moby_dick.txt")
moby_fd=nltk.FreqDist(moby)
moby_fd_100=moby_fd.most_common(100)

# %%
alice_100=[words[0] for words in alice_fd_100 ]
moby_100=[words[0] for words in moby_fd_100]

# %%
set(alice_100)-set(moby_100)
# Out:
# {u"!'",
#  u'*',
#  u",'",
#  u".'",
#  u':',
#  u"?'",
#  u'Alice',
#  u'Gryphon',
#  u'Hatter',
#  u'King',
#  u'Mock',
#  u'Queen',
#  u'Turtle',
#  u'again',
#  u'began',
#  u'can',
#  u'could',
#  u'did',
#  u'do',
#  u'don',
#  u'herself',
#  u'know',
#  u'little',
#  u'll',
#  u'm',
#  u'much',
#  u'off',
#  u'quite',
#  u'said',
#  u'see',
#  u'she',
#  u't',
#  u'thought',
#  u'way',
#  u'went',
#  u'your'}

# %%
set(moby_100)-set(alice_100)
# Out:
# {u'!"',
#  u'"',
#  u'."',
#  u'?',
#  u'Ahab',
#  u'But',
#  u'any',
#  u'are',
#  u'been',
#  u'boat',
#  u'from',
#  u'head',
#  u'him',
#  u'long',
#  u'man',
#  u'more',
#  u'now',
#  u'old',
#  u'only',
#  u'other',
#  u'over',
#  u'sea',
#  u'ship',
#  u'some',
#  u'such',
#  u'than',
#  u'their',
#  u'these',
#  u'though',
#  u'upon',
#  u'we',
#  u'whale',
#  u'which',
#  u'who',
#  u'will',
#  u'ye'}
